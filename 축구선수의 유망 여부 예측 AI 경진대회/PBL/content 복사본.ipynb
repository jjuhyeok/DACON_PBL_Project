# %%
#hiddencell

# %% [markdown]
# # Stage 4

# %% [markdown]
# # 1. 데이터 불러오기
#
# [문제 1]
# CSV파일을 데이터프레임(DataFrame)형태로 불러와 봅시다.

# %%
import ___ as __

train = pd.___('train.csv')
test = pd.___('test.csv')
submission = pd.___('sample_submission.csv')

# %%
#checkcode



아직 작설 ㅌ

# %% [markdown]
# ### Inst.
#
# 라이브러리를 이용해 CSV를 데이터프레임으로 불러요

# %% [markdown]
# ### Hint.
# DataFrame은 pandas 라이브러리를 불러와 사용 할 수 있어요
# pandas는 CSV파일을 불러올 수 있는 read_csv 함수를 제공해줘요.

# %% [markdown]
# ### Solution.
# import pandas as pd
#
# train = pd.read_csv('train.csv')
# test = pd.read_csv('test.csv')
# submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # 2. 타겟 피처 확인
# [문제2]
# 이번 데이터에서 예측해야하는 피처인 'Prospect' 피처를 확인해 보아요

# %%
train.___[___]

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# 이제 본격적으로 데이터와 인공지능 모델을 활용하기 전 <Br>
#
# 예측해야 하는 피처인 'Prospect'를 봐 볼까요? <Br>

# %% [markdown]
# ### Hint.
# 전 Stage에서 pandas의 loc와 iloc의 메소드에 대해 배웠어요.

# %% [markdown]
# ### Solution.
# train.loc[:,'Prospect']

# %% [markdown]
# # 3. 특성 데이터와 예측 데이터 나누기

# %%
train_x = train.drop(['Prospect'], axis=1)
train_y = train['Prospect']

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# 보통 머신러닝 모델은 특성 데이터를 입력으로 받아 예측 데이터를 예측하는 것이 목적입니다. <Br>
#
# 따라서 train 데이터를 특성 데이터와(train_x) 예측 데이터(train_y)로 분리하여 모델 학습에 활용합니다.<Br>
#
# 아때 drop이란 메소드는 train에 존재하는 피처를 drop 시키는 의미이고, axis 를 1로 설정하면 피처, 0으로 설정하면 인덱스를 drop 하게 됩니다. <Br>
#
# 그렇게 train_x에는 예측 피처를 제외한 데이터들만, train_y 에는 예측 피처 데이터만 존재합니다. <Br>

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty

# %% [markdown]
# # 4. 모델 불러오기(Logistic Regression)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# 드디어 인공지능 모델을 사용해보는 시간이에요! <Br>
#
# 간단한 선형 모델인 LogisticRegression을 사용해봅시다 <Br>
#
# 먼저 Logistic Regression은 사이킷런 라이브러리에서 간단하게 불러와서 사용할 수 있어요 <Br>
#
# 사이킷런은 파이썬에서 머신 러닝 알고리즘을 사용하기 쉽도록 많은 도구들을 제공하는 패키지 중 하나입니다 <Br>
#
# LogisticRegression은 이 패키지에서 제공하는 로지스틱 회귀 모델을 구현한 클래스입니다. <Br>
#
# 현재 LogisticRegression이 model에 저장된 상태에요

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty

# %% [markdown]
# # 5. 모델 학습

# %%
model.fit(train_x,train_y)

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# 전 셀에서 모델을 불러왔으니 예측을 위한 학습을 해야겠죠? <Br>
#
# 전 셀에서 Logistic Regression 모델이 model에 저장되어 있으니, <Br>
#
# fit 메소드를 통해 전 셀에서 나눠줬던 train_x, train_y를 이용해 학습을 시작해요 <Br>

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty

# %% [markdown]
# # 6. 예측

# %%
model.predict(test)

# %%
#checkcode
#empty

# %% [markdown]
# ### Inst.
#
# 자 이제 fit 메소드를 통해 학습을 끝낸 모델이 예측을 진행해야겠죠?<Br>
#
# predict 메소드를 이용해 예측을 진행해요

# %% [markdown]
# ### Hint.
# empty

# %% [markdown]
# ### Solution.
# empty
